# %%
from matplotlib import pyplot as plt
import pandas as pd
from matplotlib import rcParams
rcParams["figure.dpi"] = 400
import os
import dataAgglomeration as da

# %%
pa = pd.read_csv('postProcessing/probes/0.0208/pa', sep=None,
                 skipinitialspace=True, skiprows=range(7),
                 names=["time","probe1","probe2","probe3","probe4","probe5"])
# Out:
# /tmp/ipykernel_2518036/2827580681.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   pa = pd.read_csv('postProcessing/probes/0.0208/pa', sep=None,

# %%
rcParams["figure.dpi"] = 400
plt.plot(pa['time'].iloc[-1200:], pa['probe1'].iloc[-1200:], label="center")
#plt.plot(pa['time'].iloc[-1200:], pa['probe2'].iloc[-1200:], label="right")
#plt.plot(pa['time'].iloc[:1200], pa['probe1'].iloc[:1200], label="center")
#plt.plot(pa['time'].iloc[:1200], pa['probe2'].iloc[:1200],label="right")
#plt.plot(pa['time'].iloc[:1200], pa['probe3'].iloc[:1200],label="left")
plt.plot(pa['time'].iloc[-1200:], pa['probe4'].iloc[-1200:],label="up")
#plt.plot(pa['time'].iloc[:1200], pa['probe5'].iloc[:1200],label="down")
plt.legend()
plt.show()

# %%
rcParams["figure.dpi"] = 400
plt.plot(pa['time'].iloc[:1200], pa['probe1'].iloc[:1200], label="center")
#plt.plot(pa['time'].iloc[:1200], pa['probe2'].iloc[:1200],label="right")
#plt.plot(pa['time'].iloc[:1200], pa['probe3'].iloc[:1200],label="left")
plt.plot(pa['time'].iloc[:1200], pa['probe4'].iloc[:1200],label="up")
#plt.plot(pa['time'].iloc[:1200], pa['probe5'].iloc[:1200],label="down")
plt.legend()
plt.show()

# %%
[x / 10.0 for x in range(5, 50, 15)]
# Out:
# [0.5, 2.0, 3.5]

# %%
print(" ".join(str(x) for x in [x / 100.0 for x in range(100, 200, 2)]))
# Out:
# 1.0 1.02 1.04 1.06 1.08 1.1 1.12 1.14 1.16 1.18 1.2 1.22 1.24 1.26 1.28 1.3 1.32 1.34 1.36 1.38 1.4 1.42 1.44 1.46 1.48 1.5 1.52 1.54 1.56 1.58 1.6 1.62 1.64 1.66 1.68 1.7 1.72 1.74 1.76 1.78 1.8 1.82 1.84 1.86 1.88 1.9 1.92 1.94 1.96 1.98

# %%
# Out:
# Variants without valid data:
# ----------------------------
# #Variation | Reason
# ----------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 5>()
#       2 agglomerator = da.data_agglomerator("FrOnRefl.parameter","SumFrefl.dat",
#       3                                      "./Group1-FrOnRefl_00000_templateCase")
#       4 agglomerator.show_failed_variations()
# ----> 5 agglomerator.write_agglomerated_study_data("Group1-FrOnRefl.csv")
#       6 dframe_isoAdv_risingU = agglomerator.study_dataframe()
#       7 dframe_isoAdv_risingU = dframe_isoAdv_risingU.sort_index()
#
# File ~/transfer_Jun/argo/cases/scripts/modules/dataAgglomeration.py:432, in data_agglomerator.write_agglomerated_study_data(self, file_name, path)
#     422 def write_agglomerated_study_data(self, file_name="", path=""):
#     423     """
# ...
