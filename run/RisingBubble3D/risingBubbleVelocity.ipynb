# %%
#import sys
#print(sys.path)
#sys.path.remove('/home/local/CSI/jl95muce/transfer_Jun/argo/cases/scripts/modules')
#sys.path.append('/transfer/Jun/lent/cases/scripts/modules')
import pandas as pd
#import dataAgglomeration as datglom 
import matplotlib.pyplot as plt
from matplotlib import rcParams
#from notebookPlotting  import plot_dframe

# %%
dframe_mesh_sI_N60_8D_Mo848_00=pd.read_csv('ref-Anjos2014.parameter_00000_template_copy_block/bubblepproc.dat', sep='\s+')

# %%
# Out:
#          time  magVelocity    x-Velocity    y-Velocity  z-Velocity  \
# 0    0.000000     0.017108 -2.792380e-08 -2.792090e-08    0.017108
# 1    0.000978     0.017108 -2.792380e-08 -2.792090e-08    0.017108
# 2    0.001957     0.031566 -5.671260e-08 -5.671380e-08    0.031566
# 3    0.002935     0.044169 -9.705190e-08 -9.705560e-08    0.044169
# 4    0.003914     0.055291 -1.118140e-07 -1.118120e-07    0.055291
# ..        ...          ...           ...           ...         ...
# 323  0.316049     0.186521 -3.426230e-06 -3.426230e-06    0.186521
# 324  0.317028     0.186545 -3.237510e-06 -3.237510e-06    0.186545
# 325  0.318006     0.186642 -3.013710e-06 -3.013710e-06    0.186642
# 326  0.318985     0.186784 -2.768200e-06 -2.768200e-06    0.186784
# 327  0.319963     0.186972 -2.697470e-06 -2.697470e-06    0.186972
#
#      bubbleVolume  bubbleArea  bubbleCenterx  bubbleCentery  bubbleCenterz  \
# 0        0.000009    0.001942  -1.325890e-11  -1.325890e-11       0.000012
# ...

# %%
rcParams["figure.dpi"] = 300
g=9.80665
D=0.01305*2
ref_value=0.354

dframe_mesh_sI_N60_8D_Mo848_00=pd.read_csv('ref-Anjos2014.parameter_00000_template_copy_block/bubblepproc.dat', sep='\s+')
dframe_mesh_sI_N60_8D_Mo848_01=pd.read_csv('ref-Anjos2014.parameter_00001_template_copy_block/bubblepproc.dat', sep='\s+')
dframe_mesh_sI_N60_8D_Mo848_02=pd.read_csv('ref-Anjos2014.parameter_00002_template_copy_block/bubblepproc.dat', sep='\s+')
dframe_mesh_sI_N60_8D_Mo848_03=pd.read_csv('ref-Anjos2014.parameter_00003_template_copy_block/bubblepproc.dat', sep='\s+')


plt.plot(dframe_mesh_sI_N60_8D_Mo848_00["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo848_00["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N64_8D_0.1Tc')
plt.plot(dframe_mesh_sI_N60_8D_Mo848_01["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo848_01["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N96_8D_0.1Tc')
plt.plot(dframe_mesh_sI_N60_8D_Mo848_02["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo848_02["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N128_8D_0.1Tc')
plt.plot(dframe_mesh_sI_N60_8D_Mo848_03["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo848_03["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N160_8D_0.1Tc')

dframe_BLUE_Mo848= pd.read_csv('history.dat',sep='\s+',header=None,skipinitialspace=True)
dframe_extract_Mo848=pd.read_csv('Mo848.csv')
plt.plot(dframe_extract_Mo848['x'],dframe_extract_Mo848['Velocity'],label='Anjos2014')
plt.plot(dframe_BLUE_Mo848.iloc[:,0]/(D/g)**0.5, dframe_BLUE_Mo848.iloc[:,2]/(g*D)**0.5,label='BLUE_N256³')
plt.axhline(ref_value, color='blue', linestyle = '-.', label='Hua2007')
plt.axhline(2.47*2.73/(1350*0.0261*(D*g)**0.5), color='black',linestyle = '--', label='exp_Bahga1981')
plt.xlim(left=0,right=6.01)
plt.title("Mo=848, nu_max")
plt.ylabel("Normalized buble rising velocity")
plt.xlabel("Normalized time")
#plt.legend()
plt.legend(bbox_to_anchor=(0, -0.122), loc="upper left",ncol=2)#, bbox_to_anchor=(1, 0.5))

# %%
rcParams["figure.dpi"] = 300
g=9.80665
D=0.01305*2
ref_value=0.602
ref_exp=0.617972373

dframe_mesh_sI_N60_8D_Mo1d31_00=pd.read_csv('Mo1d31-Anjos2014.parameter_00000_template_copy_block/bubblepproc.dat', sep='\s+')
dframe_mesh_sI_N60_8D_Mo1d31_01=pd.read_csv('Mo1d31-Anjos2014.parameter_00001_template_copy_block/bubblepproc.dat', sep='\s+')
dframe_mesh_sI_N60_8D_Mo1d31_02=pd.read_csv('Mo1d31-Anjos2014.parameter_00002_template_copy_block/bubblepproc.dat', sep='\s+')
dframe_mesh_sI_N60_8D_Mo1d31_03=pd.read_csv('Mo1d31-Anjos2014.parameter_00003_template_copy_block/bubblepproc.dat', sep='\s+')

#plt.plot(dframe_mesh_sI_N60_8D_Mo1d31_00["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo1d31_00["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N64_8D_0.1Tc')
#plt.plot(dframe_mesh_sI_N60_8D_Mo1d31_01["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo1d31_01["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N96_8D_0.1Tc')
plt.plot(dframe_mesh_sI_N60_8D_Mo1d31_02["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo1d31_02["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N128_8D_0.1Tc')
plt.plot(dframe_mesh_sI_N60_8D_Mo1d31_03["time"]/(D/g)**0.5, dframe_mesh_sI_N60_8D_Mo1d31_03["magVelocity"]/(g*D)**0.5,"-.",label='interFlow_N160_8D_0.1Tc')

dframe_extract_Mo1d31=pd.read_csv('Mo1d31.csv')
plt.plot(dframe_extract_Mo1d31['x'],dframe_extract_Mo1d31['Velocity'],label='Anjos2014')
plt.axhline(ref_value, color='blue',linestyle = '-.', label='ref_Hua2017')
plt.axhline(ref_exp,color='black', linestyle = '--', label='exp_Bhaga1979')
plt.title("Mo=1.31, nu_min")
plt.ylabel("Normalized buble rising velocity")
plt.xlabel("Normalized time")
plt.legend(bbox_to_anchor=(0, -0.122), loc="upper left",ncol=2)#, bbox_to_anchor=(1, 0.5))

# %%
rcParams["figure.dpi"] = 300
g=9.80665
D=0.01305*2
ref_value=0.602

dframe_origMuSt_mesh_sI_N60_8D_Mo848_00=pd.read_csv('origMuSt_mesh_Mo1d31-Anjos2014.parameter_00000_template_copy_block/risingBubbleResults.csv')
dframe_origMuSt_mesh_sI_N60_8D_Mo848_01=pd.read_csv('origMuSt_mesh_Mo1d31-Anjos2014.parameter_00001_template_copy_block/risingBubbleResults.csv')
dframe_origMuSt_mesh_sI_N60_8D_Mo848_02=pd.read_csv('origMuSt_mesh_Mo1d31-Anjos2014.parameter_00002_template_copy_block/risingBubbleResults.csv')
dframe_origMuSt_mesh_sI_N60_8D_Mo848_03=pd.read_csv('origMuSt_mesh_Mo1d31-Anjos2014.parameter_00003_template_copy_block/risingBubbleResults.csv')

plt.plot(dframe_origMuSt_mesh_sI_N60_8D_Mo848_00["time"]/(D/g)**0.5, dframe_origMuSt_mesh_sI_N60_8D_Mo848_00["average velocity magnitude"]/(g*D)**0.5,"-.",label='origMuSt_N64_8D_0.1Tc')
plt.plot(dframe_origMuSt_mesh_sI_N60_8D_Mo848_01["time"]/(D/g)**0.5, dframe_origMuSt_mesh_sI_N60_8D_Mo848_01["average velocity magnitude"]/(g*D)**0.5,"-.",label='origMuSt_N96_8D_0.1Tc')
plt.plot(dframe_origMuSt_mesh_sI_N60_8D_Mo848_02["time"]/(D/g)**0.5, dframe_origMuSt_mesh_sI_N60_8D_Mo848_02["average velocity magnitude"]/(g*D)**0.5,"-.",label='origMuSt_N128_8D_0.1Tc')
plt.plot(dframe_origMuSt_mesh_sI_N60_8D_Mo848_03["time"]/(D/g)**0.5, dframe_origMuSt_mesh_sI_N60_8D_Mo848_03["average velocity magnitude"]/(g*D)**0.5,"-.",label='origMuSt_N160_8D_0.1Tc')

#plt.plot(dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_00["time"]/(D/g)**0.5, dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_00["average velocity magnitude"]/(g*D)**0.5,"-.",label='blendedMusemiImpST_N64_8D_0.1Tc')
#plt.plot(dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_01["time"]/(D/g)**0.5, dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_01["average velocity magnitude"]/(g*D)**0.5,"-.",label='blendedMusemiImpST_N96_8D_0.1Tc')
#plt.plot(dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_02["time"]/(D/g)**0.5, dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_02["average velocity magnitude"]/(g*D)**0.5,"-.",label='blendedMusemiImpST_N128_8D_0.1Tc')
#plt.plot(dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_03["time"]/(D/g)**0.5, dframe_blendedMusemiImpST_mesh_sI_N60_8D_Mo848_03["average velocity magnitude"]/(g*D)**0.5,"-.",label='blendedMusemiImpST_N160_8D_0.1Tc')

dframe_extract_Mo1d31=pd.read_csv('Mo1d31.csv')
plt.plot(dframe_extract_Mo1d31['x'],dframe_extract_Mo1d31['Velocity'],label='Anjos2014')
plt.axhline(ref_value, color='blue',linestyle = '-.', label='ref_Hua2017')
plt.axhline(ref_exp,color='black', linestyle = '--', label='exp_Bhaga1979')
plt.title("Mo=1.31, nu_min")
plt.ylabel("Normalized buble rising velocity")
plt.xlabel("Normalized time")
plt.legend(bbox_to_anchor=(0, -0.122), loc="upper left",ncol=2)#, bbox_to_anchor=(1, 0.5))

# %%
rcParams["figure.dpi"] = 300
g=9.80665
D=0.01305*2
ref_value=0.502
#plt.plot(dframe_N60_Mo41d1["time"]/(D/g)**0.5, dframe_N60_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60')
#plt.plot(dframe_N80_Mo41d1["time"]/(D/g)**0.5, dframe_N80_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N80')
#plt.plot(dframe_N60_Vcor_Mo41d1["time"]/(D/g)**0.5, dframe_N60_Vcor_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60_Vcor')
#plt.plot(dframe_N80_Vcor_Mo41d1["time"]/(D/g)**0.5, dframe_N80_Vcor_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N80_Vcor')
plt.plot(dframe_N60_8Dx8Dx8D_Mo41d1["time"]/(D/g)**0.5, dframe_N60_8Dx8Dx8D_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60_8D_0.035Tc')
plt.plot(dframe_N80_8Dx8Dx8D_Mo41d1["time"]/(D/g)**0.5, dframe_N80_8Dx8Dx8D_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N80_8D_0.035Tc')
plt.plot(dframe_N60_8D_smaller_Mo41d1["time"]/(D/g)**0.5, dframe_N60_8D_smaller_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60_8D_maxCFL0.01')
plt.plot(dframe_N60_8D_smaller1_Mo41d1["time"]/(D/g)**0.5, dframe_N60_8D_smaller1_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60_8D8D_0.0175Tc')
#plt.plot(dframe_N60_8D_fixTS_Mo41d1["time"]/(D/g)**0.5, dframe_N60_8D_fixTS_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60_8D_0.009Tc')
#plt.plot(dframe_N80_8D_fixTS_Mo41d1["time"]/(D/g)**0.5, dframe_N80_8D_fixTS_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N80_8D_0.009Tc')
plt.plot(dframe_N60_8D_fixTS0d015_Mo41d1["time"]/(D/g)**0.5, dframe_N60_8D_fixTS0d015_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N60_8D_0.015Tc')
plt.plot(dframe_N80_8D_fixTS0d015_Mo41d1["time"]/(D/g)**0.5, dframe_N80_8D_fixTS0d015_Mo41d1["average velocity magnitude"]/(g*D)**0.5,label='N80_8D_0.015Tc')


plt.plot(dframe_extract_Mo41d1['x'],dframe_extract_Mo41d1['Velocity'],label='Anjos2014')
plt.axhline(ref_value, linestyle = '-.', label='ref')
plt.title("Mo=41.1, nu_mid")
plt.ylabel("Normalized buble rising velocity")
plt.xlabel("Normalized time")
plt.legend()
